# %%
# This code will create a table for each chromosome showing the
# scaled median coverage for each position in which coding regions occur

# Step 1: Check working directory
import os
os.chdir('/Users/evaedwards/Final-Year-Project/Datasets/TXT')
print(os.getcwd())

# Step 2: Make txt. file for the chromosome i.e CP034456
import pandas as pd
import glob

# Define input and output file paths
input_files = glob.glob("TXT/*.txt")  # Adjust to match your directory
output_folder = "CP034462_txt/"  # Folder to store filtered files
os.makedirs(output_folder, exist_ok=True)  # Create folder if it doesn't exist

# Process each file
for file in input_files:
    strain_name = os.path.basename(file).replace(".txt", "")  # Extract strain name
    
    # Load the coverage data (assuming tab-separated format, no headers)
    df = pd.read_csv(file, sep="\t", header=None, names=["Chromosome", "Position", "Coverage"])
    
    # Filter only for the chromosome i.e CP034456
    df_filtered = df[(df["Chromosome"] == "CP034462")]
    
    # Save the filtered data - change name for the chromosome i.e CP034456
    output_file = os.path.join(output_folder, f"{strain_name.upper()}_CH62.txt")
    df_filtered.to_csv(output_file, sep="\t", index=False, header=False)
    
    print(f"Saved filtered data for {strain_name} to {output_file}")

# Step 3: Make the appropriate gbk file for the chromosome of interest i.e CP034456
# so we can then emalgamate

from Bio import SeqIO
import pandas as pd

# File paths
genbank_file = "GCA_004217705.1_ASM421770v1_genomic-1.gbk"
record_id = "CP034462.1" # Change this to the appropriate chromosome

# Initialize an empty list to store the gene information
gene_data = []

# Parse the GenBank file and find the specific record by ID
from Bio import SeqIO

with open(genbank_file, "r") as handle:
    for record in SeqIO.parse(handle, "genbank"):
        if record.id == record_id:
            for feature in record.features:
                if feature.type == "CDS":
                    gene_name = feature.qualifiers.get("gene", ["unknown"])[0]
                    product = feature.qualifiers.get("product", ["unknown"])[0]
                    strand = "+" if feature.strand == 1 else "-"
                    
                    gene_info = {
                        "Gene": gene_name,
                        "Product": product,
                        "Start Position": int(feature.location.start),
                        "End Position": int(feature.location.end),
                        "Strand": strand
                    }
                    gene_data.append(gene_info)

# Print or store results
print(gene_data)

# Create a DataFrame from the filtered gene data
df = pd.DataFrame(gene_data)

# Display the table
print(df)

# Save the filtered table to a CSV file - change to appropraite chromosome
df.to_csv("AnnotatedGenome_CP62.csv", index=False)

# Step 4: 

import os
import glob
import pandas as pd
import numpy as np

# Define paths
base_dir = "/Users/evaedwards/Final-Year-Project/Datasets/TXT"
annotated_file = os.path.join(base_dir, "AnnotatedGenome_CP62.csv")
coverage_files = glob.glob(os.path.join(base_dir, "CP034462_txt", "*.txt"))
wg_median_file = os.path.join(base_dir, "WG_Median_Coverage_CAPITALIZED.csv")
apc_median_file = os.path.join(base_dir, "WG_Median_Coverage_APC.csv")  # Added APC median coverage file

# Load annotated genome data
genes_df = pd.read_csv(annotated_file)

# Load whole-genome median coverage data
wg_median_df = pd.read_csv(wg_median_file)
wg_median_dict = dict(zip(wg_median_df["Strain"], wg_median_df["Median Coverage"]))  # {Strain: MedianCoverage}

# Load APC median coverage data
apc_median_df = pd.read_csv(apc_median_file)
wg_median_dict.update(dict(zip(apc_median_df["Strain"], apc_median_df["Median Coverage"])))  # Merge APC data

# Store processed data
final_data = []

# Process each strain's coverage file
for file in coverage_files:
    strain_name = os.path.basename(file).split("_")[0].upper()  # Extract strain name
    
    # Load coverage data
    coverage_df = pd.read_csv(file, sep="\t", header=None, names=["Chromosome", "Position", "Coverage"])
    coverage_dict = dict(zip(coverage_df["Position"], coverage_df["Coverage"]))  # {Position: Coverage}
    
    # Get the whole-genome median for this strain (default to 1 if missing to avoid division errors)
    wg_median = wg_median_dict.get(strain_name, 1)
    
    # Process each gene
    for _, gene in genes_df.iterrows():
        gene_function = gene["Product"]
        gene_id = gene["Gene"]
        start_pos, end_pos = gene["Start Position"], gene["End Position"]
        length = end_pos - start_pos  

        # Extract coverage values within the gene range
        coverage_values = [coverage_dict[pos] for pos in range(start_pos, end_pos + 1) if pos in coverage_dict]

        # Calculate median coverage for the gene
        median_coverage = round(np.median(coverage_values)) if coverage_values else None

        # Calculate scaled coverage
        scaled_coverage = round(median_coverage / wg_median, 3) if median_coverage is not None else None

        # Store result
        final_data.append([gene_id, gene_function, start_pos, end_pos, length, strain_name, scaled_coverage])

# Convert to DataFrame
final_df = pd.DataFrame(final_data, columns=["Gene ID", "Gene Function", "Start Position", "End Position", "Length", "Strain", "Scaled Coverage"])

# Pivot table to make strains as columns
final_pivot = final_df.pivot(index=["Gene ID", "Gene Function", "Start Position", "End Position", "Length"], columns="Strain", values="Scaled Coverage")

# Reset column names for clarity
final_pivot.columns = [f"{strain}" for strain in final_pivot.columns]
final_pivot.reset_index(inplace=True)

# Save the final table
output_file = os.path.join(base_dir, "Table_CRC_CH62.csv")
final_pivot.to_csv(output_file, index=False)

# Display result
print(final_pivot.head())
# Out:
# /Users/evaedwards/Final-Year-Project/Datasets/TXT
# Saved filtered data for matc2 to CP034462_txt/MATC2_CH62.txt
# Saved filtered data for WS4 to CP034462_txt/WS4_CH62.txt
# Saved filtered data for jog19 to CP034462_txt/JOG19_CH62.txt
# Saved filtered data for WS5 to CP034462_txt/WS5_CH62.txt
# Saved filtered data for matc3 to CP034462_txt/MATC3_CH62.txt
# Saved filtered data for matc1 to CP034462_txt/MATC1_CH62.txt
# Saved filtered data for WS7 to CP034462_txt/WS7_CH62.txt
# Saved filtered data for WS6 to CP034462_txt/WS6_CH62.txt
# Saved filtered data for matc4 to CP034462_txt/MATC4_CH62.txt
# Saved filtered data for WS2 to CP034462_txt/WS2_CH62.txt
# Saved filtered data for WS3 to CP034462_txt/WS3_CH62.txt
# Saved filtered data for WS1 to CP034462_txt/WS1_CH62.txt
# Saved filtered data for jog20 to CP034462_txt/JOG20_CH62.txt
# Saved filtered data for jog21 to CP034462_txt/JOG21_CH62.txt
# Saved filtered data for mat22 to CP034462_txt/MAT22_CH62.txt
# Saved filtered data for PP16 to CP034462_txt/PP16_CH62.txt
# Saved filtered data for jog1 to CP034462_txt/JOG1_CH62.txt
# Saved filtered data for jogc5 to CP034462_txt/JOGC5_CH62.txt
# Saved filtered data for jogc4 to CP034462_txt/JOGC4_CH62.txt
# Saved filtered data for PP17 to CP034462_txt/PP17_CH62.txt
# Saved filtered data for mat23 to CP034462_txt/MAT23_CH62.txt
# Saved filtered data for mat21 to CP034462_txt/MAT21_CH62.txt
# Saved filtered data for PP15 to CP034462_txt/PP15_CH62.txt
# Saved filtered data for jog2 to CP034462_txt/JOG2_CH62.txt
# Saved filtered data for NW13 to CP034462_txt/NW13_CH62.txt
# Saved filtered data for jog3 to CP034462_txt/JOG3_CH62.txt
# Saved filtered data for PP14 to CP034462_txt/PP14_CH62.txt
# Saved filtered data for APC12 to CP034462_txt/APC12_CH62.txt
# Saved filtered data for mat20 to CP034462_txt/MAT20_CH62.txt
# Saved filtered data for mat24 to CP034462_txt/MAT24_CH62.txt
# Saved filtered data for mat18 to CP034462_txt/MAT18_CH62.txt
# Saved filtered data for PP10 to CP034462_txt/PP10_CH62.txt
# Saved filtered data for jog7 to CP034462_txt/JOG7_CH62.txt
# Saved filtered data for NW16 to CP034462_txt/NW16_CH62.txt
# Saved filtered data for NW17 to CP034462_txt/NW17_CH62.txt
# Saved filtered data for jogc2 to CP034462_txt/JOGC2_CH62.txt
# Saved filtered data for jog6 to CP034462_txt/JOG6_CH62.txt
# Saved filtered data for PP11 to CP034462_txt/PP11_CH62.txt
# Saved filtered data for mat19 to CP034462_txt/MAT19_CH62.txt
# Saved filtered data for PP8 to CP034462_txt/PP8_CH62.txt
# Saved filtered data for PP13 to CP034462_txt/PP13_CH62.txt
# Saved filtered data for NW15 to CP034462_txt/NW15_CH62.txt
# Saved filtered data for NW29 to CP034462_txt/NW29_CH62.txt
# Saved filtered data for NW28 to CP034462_txt/NW28_CH62.txt
# Saved filtered data for jogc1 to CP034462_txt/JOGC1_CH62.txt
# Saved filtered data for NW14 to CP034462_txt/NW14_CH62.txt
# Saved filtered data for jog5 to CP034462_txt/JOG5_CH62.txt
# Saved filtered data for PP12 to CP034462_txt/PP12_CH62.txt
# Saved filtered data for PP9 to CP034462_txt/PP9_CH62.txt
# Saved filtered data for mat17 to CP034462_txt/MAT17_CH62.txt
# Saved filtered data for PP4 to CP034462_txt/PP4_CH62.txt
# Saved filtered data for PP23 to CP034462_txt/PP23_CH62.txt
# Saved filtered data for jog8 to CP034462_txt/JOG8_CH62.txt
# Saved filtered data for NW19 to CP034462_txt/NW19_CH62.txt
# Saved filtered data for NW31 to CP034462_txt/NW31_CH62.txt
# Saved filtered data for NW25 to CP034462_txt/NW25_CH62.txt
# Saved filtered data for NW24 to CP034462_txt/NW24_CH62.txt
# Saved filtered data for NW30 to CP034462_txt/NW30_CH62.txt
# Saved filtered data for NW18 to CP034462_txt/NW18_CH62.txt
# Saved filtered data for PP22 to CP034462_txt/PP22_CH62.txt
# Saved filtered data for PP5 to CP034462_txt/PP5_CH62.txt
# Saved filtered data for mat16 to CP034462_txt/MAT16_CH62.txt
# Saved filtered data for mat14 to CP034462_txt/MAT14_CH62.txt
# Saved filtered data for PP7 to CP034462_txt/PP7_CH62.txt
# Saved filtered data for PP20 to CP034462_txt/PP20_CH62.txt
# Saved filtered data for NW26 to CP034462_txt/NW26_CH62.txt
# Saved filtered data for NW32 to CP034462_txt/NW32_CH62.txt
# Saved filtered data for NW33 to CP034462_txt/NW33_CH62.txt
# Saved filtered data for NW27 to CP034462_txt/NW27_CH62.txt
# Saved filtered data for PP21 to CP034462_txt/PP21_CH62.txt
# Saved filtered data for PP6 to CP034462_txt/PP6_CH62.txt
# Saved filtered data for mat15 to CP034462_txt/MAT15_CH62.txt
# Saved filtered data for PP25 to CP034462_txt/PP25_CH62.txt
# Saved filtered data for PP19 to CP034462_txt/PP19_CH62.txt
# Saved filtered data for NW23 to CP034462_txt/NW23_CH62.txt
# Saved filtered data for NW36 to CP034462_txt/NW36_CH62.txt
# Saved filtered data for NW22 to CP034462_txt/NW22_CH62.txt
# Saved filtered data for PP18 to CP034462_txt/PP18_CH62.txt
# Saved filtered data for PP3 to CP034462_txt/PP3_CH62.txt
# Saved filtered data for PP24 to CP034462_txt/PP24_CH62.txt
# Saved filtered data for PP1 to CP034462_txt/PP1_CH62.txt
# Saved filtered data for NW34 to CP034462_txt/NW34_CH62.txt
# Saved filtered data for NW20 to CP034462_txt/NW20_CH62.txt
# Saved filtered data for NW21 to CP034462_txt/NW21_CH62.txt
# Saved filtered data for NW35 to CP034462_txt/NW35_CH62.txt
# Saved filtered data for mat13 to CP034462_txt/MAT13_CH62.txt
# Saved filtered data for jog10 to CP034462_txt/JOG10_CH62.txt
# Saved filtered data for jog11 to CP034462_txt/JOG11_CH62.txt
# Saved filtered data for jog13 to CP034462_txt/JOG13_CH62.txt
# Saved filtered data for jog12 to CP034462_txt/JOG12_CH62.txt
# Saved filtered data for WS11 to CP034462_txt/WS11_CH62.txt
# Saved filtered data for WS10 to CP034462_txt/WS10_CH62.txt
# Saved filtered data for WS8 to CP034462_txt/WS8_CH62.txt
# Saved filtered data for WS12 to CP034462_txt/WS12_CH62.txt
# Saved filtered data for jog15 to CP034462_txt/JOG15_CH62.txt
# Saved filtered data for jog14 to CP034462_txt/JOG14_CH62.txt
# Saved filtered data for WS9 to CP034462_txt/WS9_CH62.txt
# /opt/anaconda3/lib/python3.12/site-packages/Bio/SeqFeature.py:231: BiopythonDeprecationWarning: Please use .location.strand rather than .strand
#   warnings.warn(
# [{'Gene': 'MPUL0G00100', 'Product': 'Transcriptional activator of glycolytic enzymes', 'Start Position': 6215, 'End Position': 8981, 'Strand': '+'}, {'Gene': 'MPUL0G00110', 'Product': 'Transcriptional activator of glycolytic enzymes', 'Start Position': 10919, 'End Position': 13685, 'Strand': '+'}, {'Gene': 'MPUL0G00120', 'Product': 'Protein of unknown function DUF775', 'Start Position': 29471, 'End Position': 30095, 'Strand': '-'}, {'Gene': 'MPUL0G00130', 'Product': 'protein ATS1', 'Start Position': 30775, 'End Position': 31837, 'Strand': '-'}, {'Gene': 'MPUL0G00140', 'Product': 'SWI/SNF-related', 'Start Position': 33270, 'End Position': 36405, 'Strand': '+'}, {'Gene': 'MPUL0G00150', 'Product': 'Fe-S cluster biogenesis protein NfuA, 4Fe-4S-binding domain', 'Start Position': 37347, 'End Position': 38112, 'Strand': '+'}, {'Gene': 'unknown', 'Product': 'hypothetical protein', 'Start Position':
#             Gene                                            Product  \
# 0    MPUL0G00100    Transcriptional activator of glycolytic enzymes
# 1    MPUL0G00110    Transcriptional activator of glycolytic enzymes
# 2    MPUL0G00120                 Protein of unknown function DUF775
# 3    MPUL0G00130                                       protein ATS1
# 4    MPUL0G00140                                    SWI/SNF-related
# ..           ...                                                ...
# 218      unknown                               hypothetical protein
# 219  MPUL0G02320  Hyphally regulated cell wall GPI-anchored prot...
# 220      unknown                               hypothetical protein
# 221  MPUL0G02340                                    Exonuclease III
# 222      unknown                               hypothetical protein
#
#      Start Position  End Position Strand
# 0              6215          8981      +
# 1             10919         13685      +
# 2             29471         30095      -
# 3             30775         31837      -
# 4             33270         36405      +
# ..              ...           ...    ...
# 218          639680        640286      +
# 219          642270        651939      +
# 220          652180        653188      +
# 221          672795        676419      -
# 222          676467        679296      -
#
# [223 rows x 5 columns]
#        Gene ID                          Gene Function  Start Position  \
# 0  MPUL0F00110                    agglutinin-like ALS           23765
# 1  MPUL0F00140             LSU ribosomal protein L34E           30315
# 2  MPUL0F00150  reactive intermediate/imine deaminase           31783
# 3  MPUL0F00170        protein transport protein SEC31           37356
# 4  MPUL0F00180         kinetochore protein Mis13/DSN1           41688
#
#    End Position  Length  APC12   JOG1  JOG10  JOG11  JOG12  ...   WS11   WS12  \
# 0         24179     414  0.814  0.841  0.923  0.768  0.991  ...  0.817  0.887
# 1         30750     435  1.203  1.022  1.066  0.995  1.034  ...  0.823  0.934
# 2         32212     429  1.102  1.055  0.990  1.058  0.948  ...  0.884  0.995
# 3         41445    4089  0.958  0.973  1.010  0.971  1.026  ...  1.018  0.972
# 4         43641    1953  0.975  0.912  0.995  0.957  1.000  ...  1.006  0.972
#
#      WS2    WS3    WS4    WS5    WS6    WS7    WS8    WS9
# 0  0.894  0.859  0.917  0.962  0.856  0.768  0.846  0.914
# 1  0.945  0.966  0.911  0.953  1.040  0.924  0.981  0.968
# 2  0.990  0.879  0.906  0.938  0.941  0.886  0.974  0.962
# 3  0.980  0.933  1.033  0.976  0.950  1.016  0.987  0.984
# 4  0.935  0.906  0.956  0.995  0.975  0.962  1.000  1.011
#
# [5 rows x 102 columns]

# %%
# Step 3: Make the appropriate gbk file for the chromosome of interest i.e CP034456
# so we can then emalgamate

from Bio import SeqIO
import pandas as pd

# File paths
genbank_file = "GCA_004217705.1_ASM421770v1_genomic-1.gbk"
record_id = "CP034462.1" # Change this to the appropriate chromosome

# Initialize an empty list to store the gene information
gene_data = []

# Parse the GenBank file and find the specific record by ID
from Bio import SeqIO

with open(genbank_file, "r") as handle:
    for record in SeqIO.parse(handle, "genbank"):
        if record.id == record_id:
            for feature in record.features:
                if feature.type == "CDS":
                    gene_name = feature.qualifiers.get("gene", ["unknown"])[0]
                    product = feature.qualifiers.get("product", ["unknown"])[0]
                    strand = "+" if feature.strand == 1 else "-"
                    
                    gene_info = {
                        "Gene": gene_name,
                        "Product": product,
                        "Start Position": int(feature.location.start),
                        "End Position": int(feature.location.end),
                        "Strand": strand
                    }
                    gene_data.append(gene_info)

# Print or store results
print(gene_data)

# Create a DataFrame from the filtered gene data
df = pd.DataFrame(gene_data)

# Display the table
print(df)

# Save the filtered table to a CSV file - change to appropraite chromosome
df.to_csv("AnnotatedGenome_CP62.csv", index=False)

# Step 4: 

import os
import glob
import pandas as pd
import numpy as np

# Define paths
base_dir = "/Users/evaedwards/Final-Year-Project/Datasets/TXT"
annotated_file = os.path.join(base_dir, "AnnotatedGenome_CP62.csv")
coverage_files = glob.glob(os.path.join(base_dir, "CP034462_txt", "*.txt"))
wg_median_file = os.path.join(base_dir, "WG_Median_Coverage_CAPITALIZED.csv")
apc_median_file = os.path.join(base_dir, "WG_Median_Coverage_APC.csv")  # Added APC median coverage file

# Load annotated genome data
genes_df = pd.read_csv(annotated_file)

# Load whole-genome median coverage data
wg_median_df = pd.read_csv(wg_median_file)
wg_median_dict = dict(zip(wg_median_df["Strain"], wg_median_df["Median Coverage"]))  # {Strain: MedianCoverage}

# Load APC median coverage data
apc_median_df = pd.read_csv(apc_median_file)
wg_median_dict.update(dict(zip(apc_median_df["Strain"], apc_median_df["Median Coverage"])))  # Merge APC data

# Store processed data
final_data = []

# Process each strain's coverage file
for file in coverage_files:
    strain_name = os.path.basename(file).split("_")[0].upper()  # Extract strain name
    
    # Load coverage data
    coverage_df = pd.read_csv(file, sep="\t", header=None, names=["Chromosome", "Position", "Coverage"])
    coverage_dict = dict(zip(coverage_df["Position"], coverage_df["Coverage"]))  # {Position: Coverage}
    
    # Get the whole-genome median for this strain (default to 1 if missing to avoid division errors)
    wg_median = wg_median_dict.get(strain_name, 1)
    
    # Process each gene
    for _, gene in genes_df.iterrows():
        gene_function = gene["Product"]
        gene_id = gene["Gene"]
        start_pos, end_pos = gene["Start Position"], gene["End Position"]
        length = end_pos - start_pos  

        # Extract coverage values within the gene range
        coverage_values = [coverage_dict[pos] for pos in range(start_pos, end_pos + 1) if pos in coverage_dict]

        # Calculate median coverage for the gene
        median_coverage = round(np.median(coverage_values)) if coverage_values else None

        # Calculate scaled coverage
        scaled_coverage = round(median_coverage / wg_median, 3) if median_coverage is not None else None

        # Store result
        final_data.append([gene_id, gene_function, start_pos, end_pos, length, strain_name, scaled_coverage])

# Convert to DataFrame
final_df = pd.DataFrame(final_data, columns=["Gene ID", "Gene Function", "Start Position", "End Position", "Length", "Strain", "Scaled Coverage"])

# Pivot table to make strains as columns
final_pivot = final_df.pivot(index=["Gene ID", "Gene Function", "Start Position", "End Position", "Length"], columns="Strain", values="Scaled Coverage")

# Reset column names for clarity
final_pivot.columns = [f"{strain}" for strain in final_pivot.columns]
final_pivot.reset_index(inplace=True)

# Save the final table
output_file = os.path.join(base_dir, "Table_CRC_CH62.csv")
final_pivot.to_csv(output_file, index=False)

# Display result
print(final_pivot.head())
# Out:
# /opt/anaconda3/lib/python3.12/site-packages
': '-'}, {'Gene': 'MPUL0G00350', 'Product': 'Sds3-like', 'Start Position': 96530, 'End Position': 98294, 'Strand': '+'}, {'Gene': 'MPUL0G00360', 'Product': 'BRCA1 C Terminus (BRCT) domain-containing protein', 'Start Position': 98578, 'End Position': 100186, 'Strand': '+'}, {'Gene': 'MPUL0G00370', 'Product': 'Amino acid permease', 'Start Position': 102060, 'End Position': 103392, 'Strand': '-'}, {'Gene': 'MPUL0G00380', 'Product': 'Major Facilitator Superfamily protein', 'Start Position': 104717, 'End Position': 106241, 'Strand': '-'}, {'Gene': 'MPUL0G00390', 'Product': 'DNA-binding regulatory protein, YebC/PmpR family', 'Start Position': 108246, 'End Position': 109065, 'Strand': '+'}, {'Gene': 'MPUL0G0041 ...
#             Gene                                            Product  \
# 0    MPUL0G00100    Transcriptional activator of glycolytic enzymes
# 1    MPUL0G00110    Transcriptional activator of glycolytic enzymes
# 2    MPUL0G00120                 Protein of unknown function DUF775
# 3    MPUL0G00130                                       protein ATS1
# 4    MPUL0G00140                                    SWI/SNF-related
# ..           ...                                                ...
# 218      unknown                               hypothetical protein
# 219  MPUL0G02320  Hyphally regulated cell wall GPI-anchored prot...
# 220      unknown                               hypothetical protein
# 221  MPUL0G02340                                    Exonuclease III
# 222      unknown                               hypothetical protein
#
#      Start Position  End Position Strand
# 0              6215          8981      +
# 1             10919         13685      +
# 2             29471         30095      -
# 3             30775         31837      -
# 4             33270         36405      +
# ..              ...           ...    ...
# 218          639680        640286      +
# 219          642270        651939      +
# 220          652180        653188      +
# 221          672795        676419      -
# 222          676467        679296      -
#
# [223 rows x 5 columns]
#        Gene ID                                    Gene Function  \
# 0  MPUL0G00100  Transcriptional activator of glycolytic enzymes
# 1  MPUL0G00110  Transcriptional activator of glycolytic enzymes
# 2  MPUL0G00120               Protein of unknown function DUF775
# 3  MPUL0G00130                                     protein ATS1
# 4  MPUL0G00140                                  SWI/SNF-related
#
#    Start Position  End Position  Length   APC12    JOG1  JOG10  JOG11  JOG12  \
# 0            6215          8981    2766  10.034  10.159  7.255  6.894  7.267
# 1           10919         13685    2766  10.034  10.159  7.255  6.894  7.267
# 2           29471         30095     624   1.110   0.962  1.092  1.005  1.017
# 3           30775         31837    1062   1.017   1.005  0.944  1.029  0.974
# 4           33270         36405    3135   1.042   1.066  1.036  1.053  1.052
#
#    ...    WS11    WS12    WS2    WS3     WS4     WS5     WS6     WS7     WS8  \
# 0  ...  10.445  10.521  8.950  8.866  10.444  10.621  11.059  12.557  10.231
# 1  ...  10.445  10.521  8.950  8.866  10.444  10.621  11.059  12.557  10.231
# 2  ...   0.939   1.019  0.915  0.953   1.011   0.905   1.005   0.946   0.994
# 3  ...   0.994   0.953  0.965  0.987   1.017   0.943   0.926   1.016   0.929
# 4  ...   1.000   1.005  1.010  1.047   1.022   1.052   1.000   1.022   0.987
#
#      WS9
# 0  7.519
# 1  7.519
# 2  0.859
# 3  1.022
# 4  0.978
#
# [5 rows x 102 columns]
